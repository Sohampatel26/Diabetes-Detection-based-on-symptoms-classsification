# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
data= pd.read_csv('diabetes.csv')

# %%
x= data.iloc[:,:-1].values
y= data.iloc[:,-1].values

# %%
# prompt: I want to create a decision tree to predict y on basis of x

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)
# Creating the decision tree classifier
clf = DecisionTreeClassifier()
# Fit the classifier to the training data
clf.fit(x_train, y_train)
# Make predictions on the test data
y_pred = clf.predict(x_test)
# Evaluate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7792207792207793

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=0.2, random_state=0)

# %%
Best_Accuracy=0
for i in range(3,20):
  clf=DecisionTreeClassifier(max_depth=i,criterion= 'gini' ,min_samples_split=2)
  clf.fit(x_train,y_train)
  y_pred=clf.predict(x_test)
  accuracy=accuracy_score(y_test,y_pred)
  if accuracy>Best_Accuracy:
    Best_Accuracy=accuracy
    Best_max_depth=i
print(Best_Accuracy)
print(Best_max_depth)
# Out:
# 0.8116883116883117
# 14

# %%
clf=DecisionTreeClassifier(max_depth=9,criterion= 'gini' ,min_samples_split=2)
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=9)

# %%
# prompt: like give some x values to predict a y explicitely

# Example input values
new_data = [[6, 148, 72, 35, 0, 33.6, 0.627, 50],
            [1, 85, 66, 29, 0, 26.6, 0.351, 31]]

# Make predictions
predictions = clf.predict(new_data)

# Print the predictions
for i, prediction in enumerate(predictions):
  print(f"Prediction for input {new_data[i]}: {prediction}")
# Out:
# Prediction for input [6, 148, 72, 35, 0, 33.6, 0.627, 50]: 1
# Prediction for input [1, 85, 66, 29, 0, 26.6, 0.351, 31]: 0

# %%
from matplotlib import pyplot as plt
from sklearn import tree
plt.figure(figsize=(15, 10))
tree.plot_tree(clf, filled=True, feature_names=data.columns[:-1],
               class_names=['No Diabetes', 'Diabetes'],
               fontsize=8, rounded=True)
plt.title("Decision Tree for Diabetes Prediction")
plt.xlabel("Feature and Threshold")
plt.ylabel("Samples and Class Distribution")
plt.show()
